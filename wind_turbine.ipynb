# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.4/614.4 kB 9.2 MB/s eta 0:00:00
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/windTurbineBladeDamageDetection
# Out:
# /content/drive/MyDrive/windTurbineBladeDamageDetection

# %%
ls
# Out:
# data.yaml  runs/  test/  train/  valid/  yolov8s.pt

# %%
# %cd /content/drive/MyDrive/windTurbineBladeDamageDetection

# !yolo task=detect mode=train model=yolov8s.pt data= /content/drive/MyDrive/windTurbineBladeDamageDetection/data.yaml epochs=10 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/windTurbineBladeDamageDetection
# ...
# 100% 21.5M/21.5M [00:00<00:00, 53.2MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls /content/drive/MyDrive/windTurbineBladeDamageDetection/runs/detect/train2
# Out:
# args.yaml					     train_batch1.jpg
# confusion_matrix.png				     train_batch2.jpg
# events.out.tfevents.1691142294.b6082dc138ed.26747.0  val_batch0_labels.jpg
# F1_curve.png					     val_batch0_pred.jpg
# P_curve.png					     val_batch1_labels.jpg
# PR_curve.png					     val_batch1_pred.jpg
# R_curve.png					     val_batch2_labels.jpg
# results.csv					     val_batch2_pred.jpg
# results.png					     weights
# train_batch0.jpg

# %%
Image(filename='/content/drive/MyDrive/windTurbineBladeDamageDetection/runs/detect/train2/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/windTurbineBladeDamageDetection/runs/detect/train2/val_batch1_labels.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/windTurbineBladeDamageDetection/runs/detect/train2/val_batch0_pred.jpg', width=600)

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/windTurbineBladeDamageDetection/runs/detect/train2/weights/best.pt')  # load a pretrained YOLOv8n segmentation mode

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/windTurbineBladeDamageDetection/runs/detect/train2/weights/best.pt conf=0.25 source=/content/drive/MyDrive/windTurbineBladeDamageDetection/test/images
# Out:
# 2023-08-07 15:11:47.971865: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# image 1/214 /content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0025_03_03_png_jpg.rf.c73458e689e8138150a50688c5b9b495.jpg: 224x224 4 Damages, 12.8ms
# image 2/214 /content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0026_02_04_png_jpg.rf.564199be06a2f4b54637d35e2b5afe32.jpg: 224x224 1 Damage, 9.9ms
# image 3/214 /content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0035_03_06_png_jpg.rf.296f0751d10ee2c2625aee717adcec89.jpg: 224x224 1 Damage, 10.9ms
# image 4/214 /content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0036_03_06_png_jpg.rf.7f717d9ac0d44267199c9090c244b25d.jpg: 224x224 3 Damages, 12.9ms
# ...

# %%
results = model.predict(source='/content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0025_03_03_png_jpg.rf.c73458e689e8138150a50688c5b9b495.jpg', save=True, conf=0.2, save_txt=True, save_crop=False, line_thickness=1)  # predict on an image
# Out:
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels

# %%
results = model.predict(source='/content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0035_03_06_png_jpg.rf.296f0751d10ee2c2625aee717adcec89.jpg', save=True, conf=0.2, save_txt=True, save_crop=False, line_thickness=1)  # predict on an image
# Out:
# Results saved to runs/detect/predict
# 2 labels saved to runs/detect/predict/labels

# %%
results = model.predict(source='/content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0038_04_06_png_jpg.rf.550e5081399ad9cefccbac1e83fc1956.jpg', save=True, conf=0.2, save_txt=True, save_crop=False, line_thickness=1)  # predict on an image
# Out:
# Results saved to runs/detect/predict
# 3 labels saved to runs/detect/predict/labels

# %%
results = model.predict(source='/content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0109_01_04_png_jpg.rf.908a191b42f1399f798490ac30075727.jpg', save=True, conf=0.2, save_txt=True, save_crop=False, line_thickness=1)  # predict on an image
# Out:
# Results saved to runs/detect/predict
# 4 labels saved to runs/detect/predict/labels

# %%
results = model.predict(source='/content/drive/MyDrive/windTurbineBladeDamageDetection/test/images/DJI_0423_01_02_png_jpg.rf.b035334c7be2fb9e531bfbc086593c4e.jpg', save=True, conf=0.2, save_txt=True, save_crop=False, line_thickness=1)  # predict on an image
# Out:
# Results saved to runs/detect/predict
# 5 labels saved to runs/detect/predict/labels

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/drive/MyDrive/windTurbineBladeDamageDetection/runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")

# %% [markdown]
# # **SEGMENTATION**
